# %%
import keyword
print("The list of keywords is : ")
print(keyword.kwlist)
# Out:
# The list of keywords is :
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Value keywords
x=True
print(x)
print(type(x))
x is True
# Out:
# True
# <class 'bool'>
# True

# %%
x = "This is a truthy value"
if x is True:
    print("x is truthy")
if x:
    print("x is truthy in the if statement")
# Out:
# x is truthy in the if statement

# %%
#None
def func():
    print("hello")
x=func()
print(x)
# Out:
# hello
# None

# %%
#operator keyword
x=5
y=10
z=0
x and y and z
# Out:
# 0

# %%
a=1
while a < 10 and a%2!=0:
    print(a)
    a += 2
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# for keyword
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# for-each loop
person=["Alice", "Bob", "Charlie"]
print(person)
for name in person:
    print(name)
# Out:
# ['Alice', 'Bob', 'Charlie']
# Alice
# Bob
# Charlie

# %%
people = ["Kevin", "Creed", "Jim"]
for person in people:
   print(f"{person} was in The Office.")
# Out:
# Kevin was in The Office.
# Creed was in The Office.
# Jim was in The Office.

# %%
#f string
name="Rineeth"
age=22
print(f"I am {name} and I am {age} years old.")
# Out:
# I am Rineeth and I am 22 years old.

# %%
def greet(name):
    return f"Hello, {name}!"
print(greet("Alice"))
# Out:
# Hello, Alice!
