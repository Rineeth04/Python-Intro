# %%
Name = "rineeth"
Age = 21
print("name:",Name,"Age:",Age)
print(type(Name))
print(type(Age))
# Out:
# name: rineeth Age: 21
# <class 'str'>
# <class 'int'>

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
num = input ("Enter number :")
print(num)
name1 = input("Enter name : ")
print(name1)

# Printing type of input value
print ("type of number", type(num))
print ("type of name", type(name1))
# Out:
# 123
# rineeth
# type of number <class 'str'>
# type of name <class 'str'>

# %%
name="rineeth"
age=21
salary= 33500.50
is_student = False
age= float(age)#type conversion
salary =float(salary)
name= bool(name)
print(type(age))
print(type(salary))
print(type(name))
print(type(is_student))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>

# %%
length = float(input("enter the length: "))#5
width = float(input("enter the width: "))#4
Area = length*width
print(f"the area of rectangle is : {Area}")
# Out:
# the area of rectangle is : 20.0

# %%
#shopping cart program
item = input("what item you will buy: ")#shoes
price = float(input("what is the price: "))#200
quantity = int(input("how many would you like:"))#5
total = price*quantity #1000
print(f"you have bought {quantity} x {item}/s")
print(f"your total bill is {total}$")
# Out:
# you have bought 2 x shoes/s
# your total bill is 6000.0$

# %%
#operators
a = 5
b=6
print("addition values:",a*b)
print("subtraction values are:",a-b)
print("division values are:",a//b)
print("and operator:",a&b)
print("xor operator:",a^b)
print("left shift:",a<<b)
print("right shift:",a>>b)
print(a is b)#identity operators
print(a is not b)
# Out:
# addition values: 30
# subtraction values are: -1
# division values are: 0
# and operator: 4
# xor ooperator: 3
# left shift: 320
# right shift: 0
# False
# True

# %%
# math module will helps to find any square numbers in float.
import math
math.sqrt(100)
# Out:
# 10.0

# %%
a =9
b = 7
result = Math.sqrt(a**2 + b**2)
print(result)
# Out:
# 11.40175425099138

# %%
x = 8
result = pow(x,2)#pow function will deals with square according to 2nd parameter values(2)
print(result)
# Out:
# 64

# %%
import math
#pythagoras theorem
a=float(input("enter the value of a:"))
b=float(input("enter the values of b:"))
c=math.sqrt(pow(a,2)+pow(b,2)) #a=4,b=5
print(c)
# Out:
# 6.708203932499369

# %%
x=5 
print(id(x))
# Out:
# 140707649152040

# %%
num =9
result = 9**2 # ** is nothing but square of numbers.
print(result)
# Out:
# 81

# %%
x= input("enter the value of x:")
print("the value of x is:",x)
print(type(x)) #input will always return string type value.
# Out:
# the value of x is: 11
# <class 'str'>
