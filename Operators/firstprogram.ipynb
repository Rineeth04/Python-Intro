# %%
print("hello world")
# Out:
# hello world

# %%
a=20
b=44
print(a+b)
# Out:
# 64

# %%
def swapping(a,b):
    a,b=b,a 
    print(a)
    print(b)
swapping(5,7)
# Out:
# 7
# 5

# %%
n = list(map(int,input().split()))
print(n)
# Out:
# []

# %%
#end parameter which displays on the smae line
list = ['rineeth','rao','venepally']
for i in list:
    print(i,end=' ')
# Out:
# rineeth rao venepally

# %%
n = input("enter you name")
print("hello my name is:",n)
# Out:
# hello my name is: rineeth

# %%
n = float(input("enter your age:"))
Add = n + 1
print(n)
# Out:
# 80.0

# %%
def add(x,y):
    z=x+y
    x,y=5,10
    result=add(x,y)
    print(f"the addition of{x} and{y} is {result}")
