# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score

# %%
# Generate Random Dataset
np.random.seed(42)
X = np.random.rand(50,1) *100
Y = 2.5*X + np.random.randn(50,1) *10

# %%
# Creating ad training Linear Regression Model
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
# Predicting the Y(output) value
Y_pred = model.predict(X)

# %%
# Visualizing the data and the regression Line
plt.figure(figsize=(8,6))
plt.scatter(X,Y,color='blue',label='Data Points')
plt.plot(X,Y_pred,color='red',linewidth=2,label='Regression Line')
plt.title('Linear Regression Example')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %%
model = LinearRegression().fit(X,Y)

# %%
r_sqr = model.score(X,Y)
print('coefficient of determination:', r_sqr)
# Out:
# coefficient of determination: 0.983870444025573

# %%
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: [0.96689274]
# slope: [[2.4776566]]

# %%
y_pred = model.predict(X)
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(Y, y_pred))
print('Mean Squared Error:', mean_squared_error(Y, y_pred))
print('R2 Score:', r2_score(Y, y_pred))
# Out:
# Mean Absolute Percentage Error: 0.1409188652669779
# Mean Squared Error: 82.30711437486883
# R2 Score: 0.983870444025573
