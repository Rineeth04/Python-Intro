# %%
a = int(input("enter the value of a :"))
if a%2==0:
    print('even number')
else:
    print('odd number')
# Out:
# odd number

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
response = input("would you like food?")
if response=='yes':
    print("have some food")
else:
    print("no food for you")
# Out:
# no food for you

# %%
#ternary operators
a,b= 10,5
print("both a and b are equal" if a==b else "a is greater than b" if a>b else "b is greater than a")
# Out:
# a is greater than b

# %%
#while loop
counter = 0
while counter<10:
    counter=counter+3
    print('python loops')
else:
    print('inside else block')
# Out:
# python loops
# python loops
# python loops
# python loops
# inside else block

# %%
#continue statement
for string in "welcome to python class":
    if string=='a' or string =='s' or string=='t':
        continue
    print('current letter:',string)
# Out:
# current letter: w
# current letter: e
# current letter: l
# current letter: c
# current letter: o
# current letter: m
# current letter: e
# current letter:
# current letter: o
# current letter:
# current letter: p
# current letter: y
# current letter: h
# current letter: o
# current letter: n
# current letter:
# current letter: c
# current letter: l

# %%
print(list(range(1,10)))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
#pass statements--> these are used to create empty loops
for string in "python tutorials":
    pass
print('last letter in string is:',string)
# Out:
# last letter in string is: s

# %%
my_list = [2,6,8,7,9]
for i in range (len(my_list)):
    my_list.append(my_list[i]+1)#append is a function which apps the values to list.
print(my_list)
# Out:
# [2, 6, 8, 7, 9, 3, 7, 9, 8, 10]

# %%
numbers = [1,2,3,4]
sum=0
for num in range(len(numbers)):
    sum=sum+numbers[num]**2
print(sum)
# Out:
# 30

# %%
#random values
import random
numbers=[]
for val in range(0,5):
    numbers.append(random.randint(0,5))
for num in range(0,5):
    for i in numbers:
        if num==i:
            print(num,end=' ')
# Out:
# 0 2 4 4 4
